# %%
import pandas as pd

data = pd.read_csv('scopus (2).csv')
data.head()
# Out:
#                                              Authors  \
# 0                     Ashour S.; Hao G.Q.; Harper A.
# 1                                           Hasan Z.
# 2     Mesta C.; Kerschbaum D.; Cremen G.; Galasso C.
# 3  Gerrard R.; Kyriakou I.; Nielsen J.P.; Vodička P.
# 4                         Nordhagen S.; Neufeld L.M.
#
#                                    Author full names  \
# 0  Ashour, Samar (57204708158); Hao, Grace Qing (...
# 1                        Hasan, Zubair (36622142700)
# 2  Mesta, Carlos (57200290268); Kerschbaum, David...
# 3  Gerrard, Russell (6602678657); Kyriakou, Ioann...
# 4  Nordhagen, Stella (57204240150); Neufeld, Lynn...
#
#                                         Author(s) ID  \
# 0              57204708158; 57269468100; 57738107300
# 1                                        36622142700
# 2  57200290268; 58093366100; 57189908015; 2653724...
# 3   6602678657; 36975474700; 7404067454; 57215860956
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('punkt')

# Download stopwords if necessary
nltk.download('stopwords')

# Define stop words and stemmer
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

# Define function for text preprocessing
def preprocess(text):
    # Convert to lowercase
    text = text.lower()

    # Tokenize into words
    words = word_tokenize(text)

    # Remove stop words and stem words
    words = [stemmer.stem(word) for word in words if word not in stop_words]

    # Remove special characters
    words = [word for word in words if word.isalpha()]

    return words

# Apply preprocessing function to the text data
data['processed_text'] = data['Abstract'].apply(preprocess)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shaya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shaya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from gensim.corpora.dictionary import Dictionary
from gensim.models.tfidfmodel import TfidfModel

# Create a dictionary from the processed text data
dictionary = Dictionary(data['processed_text'])

# Convert the dictionary into a bag of words
corpus = [dictionary.doc2bow(doc) for doc in data['processed_text']]

# Apply TF-IDF weighting to the bag of words
tfidf = TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim
lda_model = gensim.models.LdaMulticore(corpus=corpus, num_topics=10, id2word=dictionary, passes=10, workers=2)
from pprint import pprint
pprint(lda_model.print_topics(num_topics=10, num_words=10))
# Out:
# [(0,
#   '0.017*"invest" + 0.016*"critic" + 0.016*"buyback" + 0.012*"cash" + '
#   '0.012*"firm" + 0.009*"financi" + 0.008*"increas" + 0.008*"manag" + '
#   '0.008*"attack" + 0.008*"advoc"'),
#  (1,
#   '0.025*"asset" + 0.023*"invest" + 0.019*"portfolio" + 0.015*"wealth" + '
#   '0.014*"american" + 0.012*"weight" + 0.012*"motiv" + 0.010*"tech" + '
#   '0.010*"angel" + 0.010*"african"'),
#  (2,
#   '0.024*"esg" + 0.024*"studi" + 0.017*"invest" + 0.014*"analysi" + '
#   '0.013*"behavior" + 0.013*"research" + 0.012*"herd" + 0.012*"factor" + '
#   '0.011*"perform" + 0.010*"financi"'),
#  (3,
#   '0.017*"invest" + 0.016*"nurs" + 0.014*"return" + 0.010*"research" + '
#   '0.009*"financ" + 0.009*"studi" + 0.008*"green" + 0.008*"project" + '
#   '0.008*"intern" + 0.008*"industri"'),
#  (4,
#   '0.028*"market" + 0.021*"bank" + 0.017*"result" + 0.013*"invest" + '
#   '0.013*"profit" + 0.012*"model" + 0.012*"strategi" + 0.012*"signific" + '
#   '0.010*"use" + 0.010*"financ"'),
#  (5,
# ...

# %%
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt

# Visualize the topics
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# C:\Users\shaya\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el666419834402315523935358606" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
from gensim.models.coherencemodel import CoherenceModel

# Compute coherence score
cm = CoherenceModel(model=lda_model, corpus=corpus, coherence='u_mass')
coherence = cm.get_coherence()
print('Coherence score:', coherence)
# Out:
# Coherence score: -6.114226891212127

# %%
# Load the dictionary and corpus
dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
corpus = gensim.corpora.MmCorpus('corpus.mm')

# Train the LDA model on the corpus
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=10)

# Calculate the perplexity of the model on the test data
test_corpus = [dictionary.doc2bow(text) for text in test_texts]
perplexity = lda_model.log_perplexity(test_corpus)
print('Perplexity:', np.exp2(-perplexity))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6664\2199459440.py in <module>
#       1 # Load the dictionary and corpus
# ----> 2 dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
#       3 corpus = gensim.corpora.MmCorpus('corpus.mm')
#       4
#       5 # Train the LDA model on the corpus
#
# ~\anaconda3\lib\site-packages\gensim\utils.py in load(cls, fname, mmap)
#     484         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     485
# --> 486         obj = unpickle(fname)
#     487         obj._load_specials(fname, mmap, compress, subname)
#     488         obj.add_lifecycle_event("loaded", fname=fname)
#
# ~\anaconda3\lib\site-packages\gensim\utils.py in unpickle(fname)
#    1458
#    1459     """
# -> 1460     with open(fname, 'rb') as f:
# ...
